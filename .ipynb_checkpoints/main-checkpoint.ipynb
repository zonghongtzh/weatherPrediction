# %%
from utils import * 

df_path = os.path.join(utils.mypath, 'Storage', 'weatherHistory_cleaned.csv')
df = pd.read_csv(df_path, index_col = [0])

del df['Timestamp']

# %%
# dist between 2 matrices https://math.stackexchange.com/questions/507742/distance-similarity-between-two-matrices

# %%
df.sort_values('eucl_dist')
# Out:
#         Summary  Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 96450  0.000000          0.0         0.710557                  0.741944
# 88962  0.000000          0.0         0.712357                  0.743600
# 88817  0.000000          0.0         0.722707                  0.753127
# 27072  0.038462          0.0         0.686527                  0.719824
# 62457  0.000000          0.0         0.692557                  0.725375
# ...         ...          ...              ...                       ...
# 82409  0.538462          0.0         0.398074                  0.363516
# 72137  0.192308          0.5         0.288903                  0.266838
# 72131  0.538462          0.5         0.309783                  0.258968
# 96451  0.000000          0.0         0.702187                  0.734239
# 96452  0.000000          0.0         0.684637                  0.718085
#
#        Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# ...

# %%
df.iloc[[88962]]
# Out:
#        Summary  Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 88962      0.0          0.0         0.712357                    0.7436
#
#        Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 88962      0.59           0.142713                0.050139              1.0
#
#        Loud Cover  Pressure (millibars)  Timestamp diff to next  eucl_dist
# 88962         0.0              0.974847                0.507082   0.003659

# %%
df
# Out:
#         Summary  Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0      0.000000          0.0         0.506975                  0.523486
# 1      0.000000          0.0         0.505085                  0.521084
# 2      0.038462          0.0         0.505445                  0.553144
# 3      0.000000          0.0         0.487805                  0.501947
# 4      0.038462          0.0         0.495365                  0.517356
# ...         ...          ...              ...                       ...
# 96448  0.000000          0.0         0.774998                  0.801259
# 96449  0.000000          0.0         0.751778                  0.779886
# 96450  0.000000          0.0         0.710557                  0.741944
# 96451  0.000000          0.0         0.702187                  0.734239
# 96452  0.000000          0.0         0.684637                  0.718085
#
#        Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# ...

# %%
result[-10:]
# Out:
# [0.4123512267635801,
#  0.40597012878581845,
#  0.3739490425229962,
#  0.2803494123298359,
#  0.13559102676129545,
#  0.04781252119236319,
#  0.015259219216238318,
#  0.0,
#  nan,
#  nan]

# %%
n = 2
target = df.iloc[-n-1:-1]
target_values = target.values

result = []
for i in range(len(df)):
    test_df = df.iloc[i:i+n]
    if test_df.index[-1] > target.index[-1]:
        result.append(np.NaN)
        continue
    
    diff_matrix = target_values - test_df.values
    dist = sum(sum(diff_matrix ** 2))
    result.append(dist)
    
    if i%10000 == 0:
        print(i)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000

# %%
test_df
# Out:
#        Summary  Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 96452      0.0          0.0         0.684637                  0.718085
#
#        Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 96452      0.61           0.092032                0.108635            0.964
#
#        Loud Cover  Pressure (millibars)  Timestamp  Timestamp diff to next  \
# 96452         0.0              0.971119   0.971876                0.507082
#
#        eucl_dist
# 96452        NaN

# %%
diff_matrix = target.values - test.values
dist = sum(sum(diff_matrix ** 2))

# %%
diff_matrix
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  1.95211952e-01,
#          2.10753044e-01, -2.90000000e-01, -5.62279375e-02,
#         -6.43454039e-01,  1.70000000e-02,  0.00000000e+00,
#          7.83654122e-04,  9.49466458e-01,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  1.79551796e-01,
#          1.97001077e-01, -2.50000000e-01, -1.31366616e-01,
#         -6.12813370e-01, -1.90000000e-02,  0.00000000e+00,
#          5.06508152e-04,  9.49466458e-01,  0.00000000e+00]])
